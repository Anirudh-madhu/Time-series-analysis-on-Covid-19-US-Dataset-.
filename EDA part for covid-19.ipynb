# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (100,50)

# %%
#!git clone https://github.com/nytimes/covid-19-data.git

# %%
os.chdir("D:\covid\covid-19-data")

# %%
os.getcwd()
# Out:
# 'D:\\covid\\covid-19-data'

# %%
data=pd.read_csv("us-counties.csv", header=0) # Reading Dataset (us- counties)

# %%
us=pd.read_csv("us-states.csv", header=0)
us.head(2)                                    # Reading dataset (us-states)
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0

# %%
data.head(2)
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0

# %%
print(data.shape)                                # how many rows and columns do data sets have
print(us.shape)
# Out:
# (45880, 6)
# (2105, 5)

# %%
data.isnull().sum()                 # Checking data as null values
# Out:
# date        0
# county      0
# state       0
# fips      626
# cases       0
# deaths      0
# dtype: int64

# %%
us.isnull().sum()
# Out:
# date      0
# state     0
# fips      0
# cases     0
# deaths    0
# dtype: int64

# %%
final=pd.concat([data, us], join='outer', sort=False)
final.head()                                                  # Concatenating both us as well as data
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
final['date']= pd.to_datetime(final['date'])        # Converting date into datetime

# %%
final.isnull().sum()
# Out:
# date         0
# county    2105
# state        0
# fips       626
# cases        0
# deaths       0
# dtype: int64

# %%
final.county.value_counts()              # checking whether how many values are there in county column
# Out:
# Washington    592
# Unknown       565
# Jefferson     447
# Franklin      406
# Jackson       363
#              ...
# Niobrara        1
# Burt            1
# Gilpin          1
# McCulloch       1
# Scurry          1
# Name: county, Length: 1570, dtype: int64

# %%
washington=final[final.state=='Washington']
washington.head()                                              # Slicing the data and taking only washington's related data
# Out:
#         date     county       state     fips  cases  deaths
# 0 2020-01-21  Snohomish  Washington  53061.0      1       0
# 1 2020-01-22  Snohomish  Washington  53061.0      1       0
# 2 2020-01-23  Snohomish  Washington  53061.0      1       0
# 4 2020-01-24  Snohomish  Washington  53061.0      1       0
# 7 2020-01-25  Snohomish  Washington  53061.0      1       0

# %%
fig= plt.figure(figsize=(10,9))

axes= fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(washington['date'], washington['cases'])

plt.show()
                                                         # Plotting date as well as cases in washington
# Out:
# C:\Users\manirudh\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
fig= plt.figure(figsize=(10,9))

axes= fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(washington['date'], washington['deaths'])

plt.show()                                                          #Based on date how many people have died in washington

# %%
Virginia=final[final.state=='Virginia']
Virginia.head()                                        # Slicing the data and taking only Virginia related data
# Out:
#            date               county     state     fips  cases  deaths
# 739  2020-03-07              Fairfax  Virginia  51059.0      1       0
# 851  2020-03-08              Fairfax  Virginia  51059.0      2       0
# 981  2020-03-09              Fairfax  Virginia  51059.0      4       0
# 982  2020-03-09  Virginia Beach city  Virginia  51810.0      1       0
# 1143 2020-03-10              Fairfax  Virginia  51059.0      4       0

# %%
fig= plt.figure(figsize=(15,9))

axes= fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(Virginia['date'], Virginia['cases'],'bo')

plt.show()                                              # checking how many cases have happened on a partcular date

# %%
fig= plt.figure(figsize=(15,9))

axes= fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(Virginia['date'], Virginia['deaths'],'bo')

plt.show()                                      # checkiing how many people have died on a particular date

# %%
fig= plt.figure(figsize=(10,9))

axes= fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(washington['state'], washington['deaths'])

plt.show()                                        # how many deaths have happened in washington

# %%
fig= plt.figure(figsize=(10,9))

axes= fig.add_axes([0.5,0.1,0.8,0.8])

axes.plot(washington['state'], washington['cases'])

plt.show()                                                   # how many cases have happened in washington

# %%
fig= plt.figure(figsize=(15,9), dpi=200)

axes= fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(Virginia['state'], Virginia['deaths'],'bo')

plt.show()                                              # how many have died in Virginia

# %%
fig= plt.figure(figsize=(15,9), dpi=200)

axes= fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(Virginia['state'], Virginia['cases'],'bo')

plt.show()                                                    # how many cases had happened in Virginia
